# %% [markdown]
# ### Import

# %%
import sys
sys.path.append('/home/lyu/AI/AImers/6th')
import pandas as pd
import numpy as np
from features.features import categorical_columns, numeric_columns
from sklearn.preprocessing import  OrdinalEncoder

# %% [markdown]
# ### Data Load

# %%
DATA_PATH = '/home/lyu/AI/AImers/6th/data'
train = pd.read_csv(DATA_PATH + '/train.csv').drop(columns=['ID'])
test = pd.read_csv(DATA_PATH + '/test.csv').drop(columns=['ID'])

# %% [markdown]
# ### 횟수 columns

# %%
# Create a function to convert the string to numeric value
def convert_to_numeric(x):
    if pd.isna(x):
        return x
    if '회 이상' in str(x):
        return 6  # '6회 이상'은 6으로 처리
    return int(str(x).replace('회', ''))

# Print column names that end with '횟수'
count_cols = [col for col in train.columns if col.endswith('횟수')]
for col in count_cols:
    train[col] = train[col].apply(convert_to_numeric)

for col in count_cols:
    test[col] = test[col].apply(convert_to_numeric)

train['총 시술 횟수'] = train['DI 시술 횟수'] + train['IVF 시술 횟수']
test['총 시술 횟수'] = test['DI 시술 횟수'] + test['IVF 시술 횟수']

# %% [markdown]
# ## 데이터 분할

# %%
train_ivf = train[train['시술 유형'] == 'IVF']
train_di = train[train['시술 유형'] == 'DI']

test_ivf = test[test['시술 유형'] == 'IVF']
test_di = test[test['시술 유형'] == 'DI']

# %% [markdown]
# 분할 후 의미없는 컬럼 제거

# %%
# Drop columns with 100% null values in train_ivf and train_di
null_cols_ivf = [col for col in train_ivf.columns if train_ivf[col].isnull().all()]
null_cols_di = [col for col in train_di.columns if train_di[col].isnull().all()]

train_ivf = train_ivf.drop(columns=null_cols_ivf)
train_di = train_di.drop(columns=null_cols_di)

test_ivf = test_ivf.drop(columns=null_cols_ivf)
test_di = test_di.drop(columns=null_cols_di)

print("Dropped columns in train_ivf:", null_cols_ivf)
print("Dropped columns in train_di:", null_cols_di)

for name, df, test_df in [("train_ivf", train_ivf, test_ivf), ("train_di", train_di, test_di)]:
    unique_cols = [col for col in df.columns if df[col].nunique(dropna=False) == 1]
    df.drop(columns=unique_cols, inplace=True)
    test_df.drop(columns=unique_cols, inplace=True)
    print(f"Dropped columns in {name}:", unique_cols)
# Out:
# Dropped columns in train_ivf: []
# Dropped columns in train_di: ['단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '배아 생성 주요 이유', '총 생성 배아 수', '미세주입된 난자 수', '미세주입에서 생성된 배아 수', '이식된 배아 수', '미세주입 배아 이식 수', '저장된 배아 수', '미세주입 후 저장된 배아 수', '해동된 배아 수', '해동 난자 수', '수집된 신선 난자 수', '저장된 신선 난자 수', '혼합된 난자 수', '파트너 정자와 혼합된 난자 수', '기증자 정자와 혼합된 난자 수', '동결 배아 사용 여부', '신선 배아 사용 여부', '기증 배아 사용 여부', '대리모 여부', 'PGD 시술 여부', 'PGS 시술 여부', '난자 채취 경과일', '난자 해동 경과일', '난자 혼합 경과일', '배아 이식 경과일', '배아 해동 경과일']
# Dropped columns in train_ivf: ['시술 유형', '불임 원인 - 여성 요인']
# Dropped columns in train_di: ['시술 유형', '배란 유도 유형', '불임 원인 - 여성 요인', '불임 원인 - 자궁경부 문제', '불임 원인 - 정자 면역학적 요인', '불임 원인 - 정자 운동성', '난자 출처', '정자 출처', '난자 기증자 나이']

# %% [markdown]
# 결측치 및 수치형 카테고리화

# %%
ivf_null_cols = [col for col in train_ivf.columns if train_ivf[col].isnull().any()]
di_null_cols = [col for col in train_di.columns if train_di[col].isnull().any()]

ivf_cat_cols = list(set(train_ivf.columns.to_list()) & (set(categorical_columns) | set(ivf_null_cols)) - set(count_cols))
ivf_num_cols = list(set(train_ivf.columns.to_list()) & (set(numeric_columns) - set(ivf_null_cols)) | set(count_cols))
di_cat_cols = list(set(train_di.columns.to_list()) & (set(categorical_columns) | set(di_null_cols))  - set(count_cols))
di_num_cols = list(set(train_di.columns.to_list()) & (set(numeric_columns) - set(di_null_cols))  | set(count_cols))

train_ivf["임신 시도 또는 마지막 임신 경과 연수"] = train_ivf["임신 시도 또는 마지막 임신 경과 연수"].astype(object)
train_ivf.loc[train_ivf["임신 시도 또는 마지막 임신 경과 연수"].between(0, 20, inclusive="both"), "임신 시도 또는 마지막 임신 경과 연수"] = "0~20"
train_ivf["난자 혼합 경과일"] = train_ivf["난자 혼합 경과일"].astype(object)
train_ivf.loc[train_ivf["난자 혼합 경과일"].between(1, 7, inclusive="both"), "난자 혼합 경과일"] = "1~7"
train_ivf["배아 해동 경과일"] = train_ivf["배아 해동 경과일"].astype(object)
train_ivf.loc[train_ivf["배아 해동 경과일"].between(1, 7, inclusive="both"), "배아 해동 경과일"] = "1~7"


test_ivf["임신 시도 또는 마지막 임신 경과 연수"] = test_ivf["임신 시도 또는 마지막 임신 경과 연수"].astype(object)
test_ivf.loc[test_ivf["임신 시도 또는 마지막 임신 경과 연수"].between(0, 20, inclusive="both"), "임신 시도 또는 마지막 임신 경과 연수"] = "0~20"
test_ivf["난자 혼합 경과일"] = test_ivf["난자 혼합 경과일"].astype(object)
test_ivf.loc[test_ivf["난자 혼합 경과일"].between(1, 7, inclusive="both"), "난자 혼합 경과일"] = "1~7"
test_ivf["배아 해동 경과일"] = test_ivf["배아 해동 경과일"].astype(object)
test_ivf.loc[test_ivf["배아 해동 경과일"].between(1, 7, inclusive="both"), "배아 해동 경과일"] = "1~7"

# %%
# 카테고리형 컬럼들을 문자열로 변환
for col in ivf_cat_cols:
    if col in train_ivf.columns:
        train_ivf[col] = train_ivf[col].astype(str)
        test_ivf[col] = test_ivf[col].astype(str)

for col in di_cat_cols:
    if col in train_di.columns:
        train_di[col] = train_di[col].astype(str)
        test_di[col] = test_di[col].astype(str)

# %% [markdown]
# ## 훈련

# %%
from supervised.automl import AutoML
automl = AutoML(mode="Compete",
                algorithms = ['Decision Tree', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Nearest Neighbors'],
                n_jobs = -1,total_time_limit=50000, eval_metric="auc", ml_task = "binary_classification",)
# Out:
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
X = train_di.drop(columns=['임신 성공 여부'])
y = train_di['임신 성공 여부']

automl.fit(X, y)
# Out:
# AutoML directory: AutoML_3
# The task is binary_classification with evaluation metric auc
# AutoML will use algorithms: ['Decision Tree', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'mix_encoding', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree auc 0.619285 trained in 2.77 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle,Stratify
# * Step simple_algorithms will try to check up to 3 models
# 1_DecisionTree auc 0.668048 trained in 5.78 seconds
# 2_DecisionTree auc 0.673056 trained in 5.7 seconds
# 3_DecisionTree auc 0.673051 trained in 5.78 seconds
# * Step default_algorithms will try to check up to 6 models
# 4_Default_LightGBM auc 0.660753 trained in 6.98 seconds
# 5_Default_Xgboost auc 0.652077 trained in 7.28 seconds
# 6_Default_CatBoost auc 0.688519 trained in 12.46 seconds
# 7_Default_RandomForest auc 0.690605 trained in 22.54 seconds
# 8_Default_ExtraTrees auc 0.687353 trained in 18.42 seconds
# 9_Default_NearestNeighbors auc 0.554802 trained in 8.06 seconds
# * Step not_so_random will try to check up to 52 models
# 19_LightGBM auc 0.673401 trained in 7.04 seconds
# 10_Xgboost auc 0.663662 trained in 7.45 seconds
# 28_CatBoost auc 0.67786 trained in 14.91 seconds
# 37_RandomForest auc 0.686964 trained in 26.57 seconds
# 46_ExtraTrees auc 0.690189 trained in 26.14 seconds
# 55_NearestNeighbors auc 0.562614 trained in 8.75 seconds
# 20_LightGBM auc 0.680395 trained in 8.09 seconds
# 11_Xgboost auc 0.639222 trained in 8.2 seconds
# 29_CatBoost auc 0.687504 trained in 16.22 seconds
# 38_RandomForest auc 0.684871 trained in 26.38 seconds
# 47_ExtraTrees auc 0.685918 trained in 22.45 seconds
# 56_NearestNeighbors auc 0.567191 trained in 9.46 seconds
# 21_LightGBM auc 0.669134 trained in 8.75 seconds
# 12_Xgboost auc 0.685097 trained in 8.82 seconds
# 30_CatBoost auc 0.690757 trained in 15.2 seconds
# 39_RandomForest auc 0.685268 trained in 25.62 seconds
# 48_ExtraTrees auc 0.691019 trained in 18.78 seconds
# 57_NearestNeighbors auc 0.567191 trained in 10.17 seconds
# 22_LightGBM auc 0.646814 trained in 9.99 seconds
# 13_Xgboost auc 0.660838 trained in 9.21 seconds
# 31_CatBoost auc 0.688837 trained in 15.49 seconds
# 40_RandomForest auc 0.686806 trained in 24.79 seconds
# 49_ExtraTrees auc 0.690426 trained in 23.54 seconds
# 58_NearestNeighbors auc 0.562614 trained in 10.7 seconds
# 23_LightGBM auc 0.666515 trained in 9.82 seconds
# 14_Xgboost auc 0.681448 trained in 10.1 seconds
# 32_CatBoost auc 0.686185 trained in 17.11 seconds
# 41_RandomForest auc 0.686766 trained in 25.66 seconds
# 50_ExtraTrees auc 0.691922 trained in 25.45 seconds
# 59_NearestNeighbors auc 0.550673 trained in 11.22 seconds
# 24_LightGBM auc 0.665276 trained in 11.47 seconds
# 15_Xgboost auc 0.668148 trained in 10.51 seconds
# 33_CatBoost auc 0.689285 trained in 15.5 seconds
# 42_RandomForest auc 0.686083 trained in 22.87 seconds
# 51_ExtraTrees auc 0.685286 trained in 23.82 seconds
# 60_NearestNeighbors auc 0.562614 trained in 12.02 seconds
# 25_LightGBM auc 0.668792 trained in 11.33 seconds
# 16_Xgboost auc 0.675934 trained in 11.44 seconds
# 34_CatBoost auc 0.657482 trained in 21.11 seconds
# 43_RandomForest auc 0.684201 trained in 30.06 seconds
# 52_ExtraTrees auc 0.68757 trained in 23.59 seconds
# 61_NearestNeighbors auc 0.552008 trained in 12.33 seconds
# 26_LightGBM auc 0.669418 trained in 11.55 seconds
# 17_Xgboost auc 0.677727 trained in 11.69 seconds
# 35_CatBoost auc 0.689548 trained in 17.61 seconds
# 44_RandomForest auc 0.688261 trained in 31.85 seconds
# 53_ExtraTrees auc 0.691915 trained in 22.74 seconds
# 27_LightGBM auc 0.669953 trained in 12.04 seconds
# 18_Xgboost auc 0.65439 trained in 12.61 seconds
# 36_CatBoost auc 0.647973 trained in 19.53 seconds
# 45_RandomForest auc 0.689741 trained in 29.67 seconds
# 54_ExtraTrees auc 0.693332 trained in 25.22 seconds
# * Step mix_encoding will try to check up to 1 model
# 12_Xgboost_categorical_mix auc 0.683446 trained in 15.05 seconds
# * Step golden_features will try to check up to 3 models
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /home/lyu/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# None 10
# Add Golden Feature: DI 출산 횟수_ratio_총 임신 횟수
# Add Golden Feature: 총 임신 횟수_ratio_DI 출산 횟수
# Add Golden Feature: DI 임신 횟수_ratio_DI 출산 횟수
# Add Golden Feature: DI 출산 횟수_ratio_DI 임신 횟수
# Add Golden Feature: 총 임신 횟수_ratio_총 출산 횟수
# Add Golden Feature: 총 출산 횟수_ratio_총 임신 횟수
# Add Golden Feature: DI 시술 횟수_ratio_총 출산 횟수
# Add Golden Feature: 총 출산 횟수_sum_DI 임신 횟수
# Add Golden Feature: DI 출산 횟수_multiply_DI 임신 횟수
# Add Golden Feature: 총 출산 횟수_ratio_DI 시술 횟수
# Created 10 Golden Features in 8.61 seconds.
# 54_ExtraTrees_GoldenFeatures auc 0.690511 trained in 41.23 seconds
# 50_ExtraTrees_GoldenFeatures auc 0.688212 trained in 26.34 seconds
# 53_ExtraTrees_GoldenFeatures auc 0.69077 trained in 28.2 seconds
# * Step kmeans_features will try to check up to 3 models
# 54_ExtraTrees_KMeansFeatures auc 0.6898 trained in 37.26 seconds
# 50_ExtraTrees_KMeansFeatures auc 0.688109 trained in 33.27 seconds
# 53_ExtraTrees_KMeansFeatures auc 0.688452 trained in 32.11 seconds
# * Step insert_random_feature will try to check up to 1 model
# 54_ExtraTrees_RandomFeature auc 0.690219 trained in 32.26 seconds
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 49696 (\N{HANGUL SYLLABLE SUL}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 54943 (\N{HANGUL SYLLABLE HOES}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51076 (\N{HANGUL SYLLABLE IM}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 48520 (\N{HANGUL SYLLABLE BUL}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 48176 (\N{HANGUL SYLLABLE BAE}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 46976 (\N{HANGUL SYLLABLE RAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 46608 (\N{HANGUL SYLLABLE DDO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 47561 (\N{HANGUL SYLLABLE MAG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 45212 (\N{HANGUL SYLLABLE NAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 51656 (\N{HANGUL SYLLABLE JIL}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 54872 (\N{HANGUL SYLLABLE HWAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 44417 (\N{HANGUL SYLLABLE GUNG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:701: UserWarning: Glyph 45236 (\N{HANGUL SYLLABLE NAE}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 49696 (\N{HANGUL SYLLABLE SUL}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 54943 (\N{HANGUL SYLLABLE HOES}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51076 (\N{HANGUL SYLLABLE IM}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 48520 (\N{HANGUL SYLLABLE BUL}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 48176 (\N{HANGUL SYLLABLE BAE}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 46976 (\N{HANGUL SYLLABLE RAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 46608 (\N{HANGUL SYLLABLE DDO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 47560 (\N{HANGUL SYLLABLE MA}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 47561 (\N{HANGUL SYLLABLE MAG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 45212 (\N{HANGUL SYLLABLE NAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 51656 (\N{HANGUL SYLLABLE JIL}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 54872 (\N{HANGUL SYLLABLE HWAN}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 44417 (\N{HANGUL SYLLABLE GUNG}) missing from current font.
# /home/lyu/.local/lib/python3.10/site-packages/supervised/utils/additional_metrics.py:707: UserWarning: Glyph 45236 (\N{HANGUL SYLLABLE NAE}) missing from current font.
# Drop features ['임신 시도 또는 마지막 임신 경과 연수', '불임 원인 - 배란 장애', '불임 원인 - 난관 질환', '총 시술 횟수', '부부 부 불임 원인', '시술 시기 코드', '불명확 불임 원인', 'random_feature', '여성 주 불임 원인', '불임 원인 - 정자 형태', '여성 부 불임 원인', '불임 원인 - 자궁내막증', 'IVF 출산 횟수', '불임 원인 - 정자 농도', '클리닉 내 총 시술 횟수', '부부 주 불임 원인', '특정 시술 유형']
# * Step features_selection will try to check up to 5 models
# 54_ExtraTrees_SelectedFeatures auc 0.695659 trained in 24.01 seconds
# 30_CatBoost_SelectedFeatures auc 0.687556 trained in 16.94 seconds
# 7_Default_RandomForest_SelectedFeatures auc 0.691193 trained in 25.97 seconds
# 12_Xgboost_SelectedFeatures auc 0.692741 trained in 13.93 seconds
# 20_LightGBM_SelectedFeatures auc 0.682563 trained in 13.89 seconds
# * Step hill_climbing_1 will try to check up to 27 models
# 62_ExtraTrees_SelectedFeatures auc 0.693305 trained in 30.17 seconds
# 63_ExtraTrees_SelectedFeatures auc 0.699521 trained in 22.64 seconds
# 64_ExtraTrees auc 0.68937 trained in 28.34 seconds
# 65_ExtraTrees auc 0.689602 trained in 28.76 seconds
# 66_Xgboost_SelectedFeatures auc 0.691557 trained in 14.76 seconds
# 67_Xgboost_SelectedFeatures auc 0.692562 trained in 14.78 seconds
# 68_ExtraTrees auc 0.688687 trained in 31.1 seconds
# 69_RandomForest_SelectedFeatures auc 0.68866 trained in 31.81 seconds
# 70_RandomForest_SelectedFeatures auc 0.692794 trained in 27.8 seconds
# 71_CatBoost auc 0.673695 trained in 22.92 seconds
# 72_CatBoost auc 0.68428 trained in 20.14 seconds
# 73_RandomForest auc 0.681597 trained in 34.38 seconds
# 74_RandomForest auc 0.687387 trained in 28.47 seconds
# 75_RandomForest auc 0.687538 trained in 31.9 seconds
# 76_RandomForest auc 0.689345 trained in 38.62 seconds
# 77_CatBoost auc 0.682951 trained in 21.71 seconds
# 78_CatBoost auc 0.688938 trained in 20.92 seconds
# 79_CatBoost auc 0.655705 trained in 20.96 seconds
# 80_CatBoost auc 0.687308 trained in 20.17 seconds
# 81_Xgboost auc 0.66788 trained in 16.26 seconds
# 82_Xgboost auc 0.683125 trained in 16.32 seconds
# 83_Xgboost auc 0.681374 trained in 18.64 seconds
# 84_Xgboost auc 0.679829 trained in 18.46 seconds
# 85_LightGBM_SelectedFeatures auc 0.682563 trained in 16.5 seconds
# 86_LightGBM auc 0.680395 trained in 16.84 seconds
# 87_LightGBM auc 0.673401 trained in 16.54 seconds
# 88_DecisionTree auc 0.653522 trained in 15.91 seconds
# * Step hill_climbing_2 will try to check up to 30 models
# 89_ExtraTrees_SelectedFeatures auc 0.694019 trained in 28.7 seconds
# 90_ExtraTrees_SelectedFeatures auc 0.692145 trained in 29.02 seconds
# 91_ExtraTrees auc 0.687851 trained in 31.37 seconds
# 92_RandomForest_SelectedFeatures auc 0.693216 trained in 30.3 seconds
# 93_RandomForest_SelectedFeatures auc 0.690686 trained in 28.39 seconds
# 94_Xgboost_SelectedFeatures auc 0.68925 trained in 17.67 seconds
# 95_Xgboost_SelectedFeatures auc 0.695368 trained in 17.64 seconds
# 96_Xgboost_SelectedFeatures auc 0.692009 trained in 17.93 seconds
# 97_Xgboost_SelectedFeatures auc 0.693517 trained in 17.65 seconds
# 98_Xgboost_SelectedFeatures auc 0.68796 trained in 18.24 seconds
# 99_Xgboost_SelectedFeatures auc 0.690224 trained in 17.95 seconds
# 100_RandomForest_SelectedFeatures auc 0.690988 trained in 27.94 seconds
# 101_RandomForest_SelectedFeatures auc 0.690113 trained in 26.64 seconds
# 102_CatBoost auc 0.68731 trained in 25.24 seconds
# 103_RandomForest auc 0.687862 trained in 31.75 seconds
# 104_RandomForest auc 0.688228 trained in 34.61 seconds
# 105_CatBoost auc 0.686951 trained in 23.58 seconds
# 106_CatBoost auc 0.686182 trained in 27.62 seconds
# 107_CatBoost auc 0.691974 trained in 25.11 seconds
# 108_LightGBM_SelectedFeatures auc 0.681444 trained in 18.81 seconds
# 109_LightGBM_SelectedFeatures auc 0.680532 trained in 19.36 seconds
# 110_LightGBM_SelectedFeatures auc 0.681444 trained in 18.86 seconds
# 111_LightGBM_SelectedFeatures auc 0.680532 trained in 19.48 seconds
# 112_LightGBM auc 0.685884 trained in 19.43 seconds
# 113_LightGBM auc 0.682282 trained in 20.12 seconds
# 114_DecisionTree auc 0.673398 trained in 18.9 seconds
# 115_DecisionTree auc 0.673398 trained in 19.06 seconds
# 116_DecisionTree auc 0.666066 trained in 19.21 seconds
# 117_NearestNeighbors auc 0.559892 trained in 21.15 seconds
# 118_NearestNeighbors auc 0.559892 trained in 21.25 seconds
# * Step boost_on_errors will try to check up to 1 model
# 63_ExtraTrees_SelectedFeatures_BoostOnErrors auc 0.694713 trained in 29.54 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble auc 0.707198 trained in 91.09 seconds
# * Step stack will try to check up to 49 models
# 63_ExtraTrees_SelectedFeatures_Stacked auc 0.699459 trained in 51.3 seconds
# 95_Xgboost_SelectedFeatures_Stacked auc 0.685006 trained in 22.25 seconds
# 92_RandomForest_SelectedFeatures_Stacked auc 0.699003 trained in 68.4 seconds
# 107_CatBoost_Stacked auc 0.670358 trained in 27.98 seconds
# 112_LightGBM_Stacked auc 0.675795 trained in 22.72 seconds
# 54_ExtraTrees_SelectedFeatures_Stacked auc 0.703721 trained in 48.31 seconds
# 97_Xgboost_SelectedFeatures_Stacked auc 0.688838 trained in 22.84 seconds
# 70_RandomForest_SelectedFeatures_Stacked auc 0.700853 trained in 79.64 seconds
# 30_CatBoost_Stacked auc 0.64339 trained in 55.3 seconds
# 20_LightGBM_SelectedFeatures_Stacked auc 0.645878 trained in 24.2 seconds
# 89_ExtraTrees_SelectedFeatures_Stacked auc 0.702888 trained in 69.16 seconds
# 12_Xgboost_SelectedFeatures_Stacked auc 0.681068 trained in 23.96 seconds
# 7_Default_RandomForest_SelectedFeatures_Stacked auc 0.70017 trained in 75.68 seconds
# 35_CatBoost_Stacked auc 0.670669 trained in 66.68 seconds
# 85_LightGBM_SelectedFeatures_Stacked auc 0.645878 trained in 24.59 seconds
# 54_ExtraTrees_Stacked auc 0.699649 trained in 51.18 seconds
# 67_Xgboost_SelectedFeatures_Stacked auc 0.679471 trained in 24.3 seconds
# 100_RandomForest_SelectedFeatures_Stacked auc 0.698379 trained in 75.62 seconds
# 33_CatBoost_Stacked auc 0.70215 trained in 28.81 seconds
# 113_LightGBM_Stacked auc 0.638166 trained in 27.38 seconds
# 62_ExtraTrees_SelectedFeatures_Stacked auc 0.702294 trained in 53.74 seconds
# 96_Xgboost_SelectedFeatures_Stacked auc 0.669341 trained in 25.25 seconds
# 93_RandomForest_SelectedFeatures_Stacked auc 0.696448 trained in 98.05 seconds
# 78_CatBoost_Stacked auc 0.685178 trained in 59.77 seconds
# 110_LightGBM_SelectedFeatures_Stacked auc 0.683634 trained in 24.44 seconds
# 90_ExtraTrees_SelectedFeatures_Stacked auc 0.70263 trained in 57.32 seconds
# 66_Xgboost_SelectedFeatures_Stacked auc 0.671548 trained in 25.44 seconds
# 7_Default_RandomForest_Stacked auc 0.699382 trained in 79.53 seconds
# 31_CatBoost_Stacked auc 0.68439 trained in 68.02 seconds
# 108_LightGBM_SelectedFeatures_Stacked auc 0.683634 trained in 24.9 seconds
# 50_ExtraTrees_Stacked auc 0.701048 trained in 68.02 seconds
# 99_Xgboost_SelectedFeatures_Stacked auc 0.684459 trained in 25.41 seconds
# 101_RandomForest_SelectedFeatures_Stacked auc 0.698453 trained in 84.26 seconds
# 6_Default_CatBoost_Stacked auc 0.669128 trained in 36.0 seconds
# 111_LightGBM_SelectedFeatures_Stacked auc 0.657376 trained in 27.73 seconds
# 53_ExtraTrees_Stacked auc 0.701168 trained in 65.56 seconds
# 94_Xgboost_SelectedFeatures_Stacked auc 0.675233 trained in 26.58 seconds
# 45_RandomForest_Stacked auc 0.700356 trained in 79.06 seconds
# 30_CatBoost_SelectedFeatures_Stacked auc 0.689253 trained in 53.83 seconds
# 109_LightGBM_SelectedFeatures_Stacked auc 0.657376 trained in 28.46 seconds
# 48_ExtraTrees_Stacked auc 0.702069 trained in 57.91 seconds
# 98_Xgboost_SelectedFeatures_Stacked auc 0.672464 trained in 27.33 seconds
# 76_RandomForest_Stacked auc 0.698674 trained in 80.96 seconds
# 29_CatBoost_Stacked auc 0.700055 trained in 75.09 seconds
# 86_LightGBM_Stacked auc 0.647767 trained in 28.3 seconds
# 12_Xgboost_Stacked auc 0.680879 trained in 27.67 seconds
# 69_RandomForest_SelectedFeatures_Stacked auc 0.699473 trained in 69.35 seconds
# 102_CatBoost_Stacked auc 0.659169 trained in 39.21 seconds
# 20_LightGBM_Stacked auc 0.647767 trained in 28.79 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked auc 0.713423 trained in 171.89 seconds
# AutoML fit time: 5576.49 seconds
# AutoML best model: Ensemble_Stacked
# AutoML(algorithms=['Decision Tree', 'Random Forest', 'Extra Trees', 'LightGBM',
#                    'Xgboost', 'CatBoost', 'Nearest Neighbors'],
#        eval_metric='auc', ml_task='binary_classification', mode='Compete',
#        total_time_limit=50000)

# %%
pred_ivf = 0
pred_di = automl.predict_proba(test_di)[:, 1]

# %%
model_ivf = AutoML(results_path="AutoML_2")
pred_ivf = model_ivf.predict_proba(test_ivf)[:, 1]

# %%
print(train_ivf["임신 성공 여부"].mean(), train_di["임신 성공 여부"].mean())
print(pred_ivf.mean(), pred_di.mean())
# Out:
# 0.2616052147484604 0.12891432204736925
# 0.26165149605805804 0.1383915785866596

# %% [markdown]
# ### Submission

# %%
test_ivf = test[test['시술 유형'] == 'IVF']
test_di = test[test['시술 유형'] == 'DI']

# %%
sample_submission = pd.read_csv(DATA_PATH + '/sample_submission.csv')
sample_submission.loc[test_ivf.index, 'probability'] = pred_ivf
sample_submission.loc[test_di.index, 'probability'] = pred_di

# %%
sample_submission.to_csv('../automl.csv', index=False)

# %%
sample_submission['probability'].max(), sample_submission['probability'].min()
# Out:
# (0.7382358203023288, 0.0005671814892622001)

# %%
pred_di.max(), pred_di.min(), pred_ivf.max(), pred_ivf.min()
# Out:
# (0.39218501829312197,
#  0.03977252208582412,
#  0.7382358203023288,
#  0.0005671814892622001)
